# %% [markdown]
# ## Descripción del set de datos:
# - id: id del vehiculo, no tiene utilidad en análsis ni modelo predictivo.
# - region: Zona donde se encuentra el vehiculo, pero teniendo el estado un poco mas adelante tampoco me es de mucha utilidad.
# - price: Precio de venta del vehiculo(sera la variable respuesta en los modelos predivtivos)
# - year: Año de fabricación del vehiculo.
# - manufacturer: Fabricante.
# - model: Modelo del vehiculo.
# - condition: Estado del vehiculo.
# - cylinders : Número de cilindros que tiene el motor del vehiculo.
# - fuel: Tipo de combustible que consume.
# - odometer: Millas que tiene recorridas.
# - title_status: El 95% de los datos es "clean", no es un valor relevante ni para el analisis ni para el modelo predictivo.
# - transmission: Transmision que tiene el vehículo.
# - VIN : Número de bastidor del vehículo.
# - drive: Modo de conducción del vehiculo.
# - size: Tamaño del vehículo, categorizado en full, y el 75% son nulos, por lo que no es de utilidad.
# - type: Tipo de vehículo genérico.
# - paint_color: Color del vehiculo.
# - description: Descripcion en el anuncio.
# - county: Condado, 100% nulos.
# - state: Estado donde esta el vehículo.
# - lat: Latitud
# - long: Longitud.
# - posting_date: Fecha del anuncio.

# %% [markdown]
# # Limpieza del set de datos
# Antes de hacer un analisis de negocio, o incluso antes de realizar cualquier cálculo con un nuevo conjunto de datos, es muy importante realizar una exploración descriptiva de los mismos. Este proceso permite entender mejor qué información contiene cada variable, así como detectar posibles errores. Algunos ejemplos frecuentes son:
#
# Que una columna se haya almacenado con el tipo incorrecto: una variable numérica está siendo reconocida como texto o viceversa.
#
# Que una variable contenga valores que no tienen sentido: por ejemplo, para indicar que no se dispone del precio de una vivienda se introduce el valor 0 o un espacio en blanco.
#
# Que en una variable de tipo numérico se haya introducido una palabra en lugar de un número.
#
# Además, este análisis inicial puede dar pistas sobre qué variables son adecuadas como predictores en un modelo (más sobre esto en los siguientes apartados).

# %%
import pandas as pd
import numpy as np
import re
import sidetable
from scipy import stats
import math
import pickle
pd.options.display.max_columns = None

from Levenshtein import distance # Dandole unos modelos, te compara una columna y te devuelve los valores de esta transformados al mas parecido del modelo.

#librerias limpieza de nulos
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

#Normalizacion
from sklearn.preprocessing import MinMaxScaler


#Estandarización
## esto es un metodo que estandariza automaticamente todas las columnas del dataframe que le pasemos
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

#Normalizacion
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder  
from sklearn.preprocessing import OrdinalEncoder



#libreria para el balanceo
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# librerías de visualización
from pprint import pprint
import seaborn as sns
import matplotlib.pyplot as plt

# librerías para crear el modelo
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.model_selection import GridSearchCV
from sklearn import tree
from xgboost import XGBRegressor
from  sklearn.ensemble import GradientBoostingRegressor


# para calcular las métricas regresion logistica
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import f1_score 
from sklearn.metrics import cohen_kappa_score


from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("datos/vehicles.csv")
df.sample(20)
# Out:
#                 id                                                url  \
# 258777  7304052366  https://southjersey.craigslist.org/ctd/d/farmi...
# 356093  7306580886  https://knoxville.craigslist.org/ctd/d/jacksbo...
# 367321  7303130345  https://collegestation.craigslist.org/ctd/d/br...
# 223300  7311195487  https://stjoseph.craigslist.org/cto/d/clarksda...
# 236317  7305312822  https://fayetteville.craigslist.org/ctd/d/merc...
# 361884  7312318428  https://tricities.craigslist.org/ctd/d/blountv...
# 124432  7309090556  https://augusta.craigslist.org/ctd/d/lexington...
# 209346  7302705705  https://saginaw.craigslist.org/ctd/d/chesaning...
# 368679  7316972508  https://dallas.craigslist.org/dal/ctd/d/arling...
# 393813  7312292704  https://norfolk.craigslist.org/ctd/d/white-mar...
# 206178  7308756494  https://lansing.craigslist.org/ctd/d/lansing-2...
# 21238   7316460728  https://bakersfield.craigslist.org/ctd/d/fonta...
# 388844  7304123951  https://vermont.craigslist.org/ctd/d/johnstown...
# 368517  7302015085  https://corpuschristi.craigslist.org/ctd/d/cor...
# 286224  7305807569  https://nd.craigslist.org/cto/d/williston-2014...
# 301163  7303578086  https://parkersburg.craigslist.org/ctd/d/parke...
# 106658  7312485618  https://orlando.craigslist.org/ctd/d/orlando-2...
# 113599  7314585400  https://miami.craigslist.org/mdc/cto/d/chicago...
# 160374  7315421624  https://omaha.craigslist.org/ctd/d/omaha-2019-...
# 189409  7308274990  https://southcoast.craigslist.org/ctd/d/new-be...
#
#                          region                             region_url  price  \
# 258777             south jersey     https://southjersey.craigslist.org  18995
# 356093                knoxville       https://knoxville.craigslist.org      0
# 367321          college station  https://collegestation.craigslist.org   2500
# 223300                st joseph        https://stjoseph.craigslist.org  24800
# 236317             fayetteville    https://fayetteville.craigslist.org  26998
# 361884               tri-cities       https://tricities.craigslist.org  25990
# 124432                  augusta         https://augusta.craigslist.org   3150
# 209346  saginaw-midland-baycity         https://saginaw.craigslist.org   5495
# 368679      dallas / fort worth          https://dallas.craigslist.org      0
# 393813  norfolk / hampton roads         https://norfolk.craigslist.org   5995
# 206178                  lansing         https://lansing.craigslist.org  35590
# 21238               bakersfield     https://bakersfield.craigslist.org  35495
# 388844                  vermont         https://vermont.craigslist.org   5995
# 368517           corpus christi   https://corpuschristi.craigslist.org  15326
# 286224             north dakota              https://nd.craigslist.org  18000
# 301163     parkersburg-marietta     https://parkersburg.craigslist.org  10990
# 106658                  orlando         https://orlando.craigslist.org   6995
# 113599            south florida           https://miami.craigslist.org  49500
# 160374   omaha / council bluffs           https://omaha.craigslist.org  19995
# 189409              south coast      https://southcoast.craigslist.org  23997
#
#           year   manufacturer                      model  condition  \
# 258777  2018.0     volkswagen                     tiguan        NaN
# 356093  2018.0          acura      mdx sport hybrid 3.0l       good
# 367321  1976.0      chevrolet                   cheyenne        NaN
# 223300  2017.0           ford           explorer limited  excellent
# 236317  2016.0  mercedes-benz                     metris        NaN
# 361884  2012.0           jeep  wrangler unlimited sahara       good
# 124432  2007.0            kia                        NaN  excellent
# 209346  2011.0          buick                      regal        NaN
# 368679  2015.0           ford                      focus        NaN
# 393813  2008.0        pontiac                     g/6 gt   like new
# 206178  2011.0          dodge   challenger srt8 coupe 2d       good
# 21238   2012.0           ford                    f-250sd        NaN
# 388844  2011.0            NaN        BLUE BIRD BLUE BIRD        NaN
# 368517  2014.0           ford                   explorer        NaN
# 286224  2014.0      chevrolet                      tahoe  excellent
# 301163  2013.0         nissan          sentra s sedan 4d       good
# 106658  2012.0       chrysler            200 convertible       good
# 113599  1987.0  mercedes-benz                    g-class        NaN
# 160374     NaN            NaN             wagen Golf GTI        NaN
# 189409  2016.0          honda              pilot touring        NaN
#
#           cylinders    fuel  odometer title_status transmission  \
# 258777          NaN     gas    9583.0        clean    automatic
# 356093  6 cylinders  hybrid   81231.0        clean    automatic
# 367321  8 cylinders     gas   99999.0        clean    automatic
# 223300  6 cylinders     gas   94127.0        clean    automatic
# 236317  4 cylinders     gas  100846.0        clean    automatic
# 361884  6 cylinders     gas   83995.0        clean        other
# 124432          NaN     gas     195.0        clean    automatic
# 209346          NaN     gas  105093.0        clean    automatic
# 368679          NaN     gas       NaN        clean       manual
# 393813  6 cylinders     gas   56926.0        clean    automatic
# 206178  8 cylinders     gas   16796.0        clean        other
# 21238           NaN  diesel  164637.0        clean    automatic
# 388844          NaN     NaN   93000.0          NaN    automatic
# 368517  6 cylinders     gas  118083.0        clean    automatic
# 286224  8 cylinders     gas   99442.0        clean    automatic
# 301163          NaN     gas   81557.0        clean        other
# 106658  4 cylinders     gas   94500.0        clean    automatic
# 113599          NaN  diesel   35000.0        clean       manual
# 160374  4 cylinders     gas   15050.0      rebuilt       manual
# 189409          NaN     gas   75952.0        clean    automatic
#
#                       VIN drive       size         type paint_color  \
# 258777  3VV3B7AX9JM010070   NaN        NaN          NaN         NaN
# 356093  5J8YD7H7XJL000395   NaN        NaN        other         NaN
# 367321                NaN   NaN        NaN          NaN         NaN
# 223300                NaN   4wd        NaN          SUV        blue
# 236317                NaN   rwd        NaN          van       brown
# 361884  1C4BJWEG2CL120352   4wd        NaN        other      silver
# 124432                NaN   NaN        NaN          NaN         NaN
# 209346                NaN   NaN        NaN          NaN         NaN
# 368679                NaN   NaN    compact    hatchback      silver
# 393813                NaN   fwd        NaN        coupe      silver
# 206178  2B3CJ7DJ7BH589702   rwd        NaN        coupe       green
# 21238   1FT7W2BT3CEB92781   4wd        NaN          NaN       white
# 388844  1BAKGC5A0BF275837   NaN        NaN          NaN         NaN
# 368517                NaN   fwd  full-size          SUV      custom
# 286224                NaN   4wd   mid-size          SUV         red
# 301163  3N1AB7AP2DL658501   fwd        NaN        sedan         red
# 106658                NaN   fwd   mid-size  convertible        blue
# 113599                NaN   NaN        NaN          NaN         NaN
# 160374  3VW5T7AU1KM006393   fwd        NaN        sedan       black
# 189409                NaN   NaN        NaN          SUV        blue
#
#                                                 image_url  \
# 258777  https://images.craigslist.org/00000_edGU0tICvA...
# 356093  https://images.craigslist.org/00z0z_3I6UTi3gdX...
# 367321  https://images.craigslist.org/00r0r_8CgEqMtEcW...
# 223300  https://images.craigslist.org/00l0l_4vblTF02ge...
# 236317  https://images.craigslist.org/00A0A_hkj7yNP1AD...
# 361884  https://images.craigslist.org/00B0B_4JeQXjI9PI...
# 124432  https://images.craigslist.org/00g0g_2rNdCLeyJK...
# 209346  https://images.craigslist.org/00v0v_gCV5WiVSV0...
# 368679  https://images.craigslist.org/00p0p_iSM0ng8kKC...
# 393813  https://images.craigslist.org/00s0s_b5N6GkvPdP...
# 206178  https://images.craigslist.org/00P0P_25B5uUcC4B...
# 21238   https://images.craigslist.org/00N0N_cOlSoMjlRx...
# 388844  https://images.craigslist.org/01515_6pCG98ikLy...
# 368517  https://images.craigslist.org/01414_5AhJacnKMR...
# 286224  https://images.craigslist.org/00s0s_eDXRO9Pdie...
# 301163  https://images.craigslist.org/00L0L_37Ad4hiDJ7...
# 106658  https://images.craigslist.org/00o0o_fy0ts6bYxI...
# 113599  https://images.craigslist.org/00N0N_gFNQXJY4Y2...
# 160374  https://images.craigslist.org/01212_bXH415RU3b...
# 189409  https://images.craigslist.org/00a0a_be84vLlNGI...
#
#                                               description  county state  \
# 258777  2018 Volkswagen Tiguan CALL Automotive Avenues...     NaN    nj
# 356093  Why Buy From Short-Redmond Ford?Short-Redmond ...     NaN    tn
# 367321  ****** 1976 Chevy Square Body******  !!!!!! CA...     NaN    tx
# 223300  2017 Explorer Limited  Virtually all the optio...     NaN    mo
# 236317  2016 Mercedes Benz Metris Conversion Van High ...     NaN    nc
# 361884  Carvana is the safer way to buy a car During t...     NaN    tn
# 124432  Columbia, South Carolina 2007 Kia Sportage  Pr...     NaN    ga
# 209346  WE HAVE OVER 500 VEHICLES IN STOCK!   See our ...     NaN    mi
# 368679  2015 Ford Focus SE Hatch     Offered by: AutoM...     NaN    tx
# 393813  2008 Pontiac G/6 GT Cpe, 3.5 v6 engine, Automa...     NaN    va
# 206178  Carvana is the safer way to buy a car During t...     NaN    mi
# 21238   2012 Ford F-250SD Lariat 4WD 4D Crew Cab  8 cy...     NaN    ca
# 388844  2011 *BLUE BIRD* *BLUE BIRD* VISION - $5,995Ca...     NaN    vt
# 368517  Most common questions about this vehicle:  Wan...     NaN    tx
# 286224  2014 chevy Tahoe for sale. Good condition! Run...     NaN    nd
# 301163  Carvana is the safer way to buy a car During t...     NaN    oh
# 106658  2012 Chrysler 200 Convertible .  One touch Pow...     NaN    fl
# 113599  Hello, I am posting a feeler ad for my 1987 Me...     NaN    fl
# 160374  2019 *Volkswagen* *Golf GTI* 2.0T S Manual Sed...     NaN    ia
# 189409  2016 Honda Pilot Touring SUV2016 Honda Pilot T...     NaN    ma
#
#               lat        long              posting_date
# 258777  40.204300  -74.177900  2021-04-09T06:09:22-0400
# 356093  36.353521  -84.153891  2021-04-14T07:40:54-0400
# 367321  30.820200  -96.305900  2021-04-07T10:30:30-0500
# 223300  39.798400  -94.517500  2021-04-22T21:56:17-0500
# 236317        NaN         NaN  2021-04-11T16:06:19-0400
# 361884  36.530000  -82.320000  2021-04-25T10:51:29-0400
# 124432  33.952308  -81.222954  2021-04-19T00:34:39-0400
# 209346  43.182400  -84.112200  2021-04-06T13:58:00-0400
# 368679  32.738487  -97.097679  2021-05-04T17:01:14-0500
# 393813  37.345188  -76.523316  2021-04-25T09:50:33-0400
# 206178  42.700000  -84.550000  2021-04-18T11:41:09-0400
# 21238   34.070311 -117.446303  2021-05-03T15:03:14-0700
# 388844  43.008105  -74.352011  2021-04-09T10:12:04-0400
# 368517  27.657870  -97.479816  2021-04-05T08:51:27-0500
# 286224  48.225592 -103.648539  2021-04-12T14:40:29-0500
# 301163  39.260000  -81.540000  2021-04-08T09:15:18-0400
# 106658  28.621400  -81.429400  2021-04-25T15:56:18-0400
# 113599  41.892300  -87.637300  2021-04-29T19:13:35-0400
# 160374  41.207382  -96.023096  2021-05-01T13:30:55-0500
# 189409  41.634700  -70.937200  2021-04-17T12:02:12-0400

# %%
df.shape
# Out:
# (426880, 26)

# %% [markdown]
# ### Al acceder a los enlaces, son paginas fake. Se eliminan al no tener utilidad.

# %%
df.drop(["url","region_url","image_url"], axis = 1, inplace = True)

# %% [markdown]
# ### Se eliminan el resto de columnas que no me valen.

# %%
df.drop(["id","region","title_status","VIN", "size", "description","county"], axis = 1, inplace= True)

# %%
df.sample(10)
# Out:
#         price    year manufacturer                         model  condition  \
# 283109   3299  2010.0          kia                          soul        NaN
# 273862  21990  2005.0         ford  econoline commercial cutaway       good
# 53716   14900  2014.0          bmw                   535i xdrive  excellent
# 255093  16495  2016.0        mazda                          cx-5        NaN
# 307733  30500  2019.0        rover               discovery sport  excellent
# 162804  12995  2016.0         ford                        taurus        NaN
# 211558  17990  2017.0       subaru                       impreza        NaN
# 237374  25000  1988.0          bmw                         325is  excellent
# 168986  26900  2017.0         ford                          f150        NaN
# 366943   6500  1992.0         jeep                      wrangler       good
#
#           cylinders fuel  odometer transmission drive       type paint_color  \
# 283109          NaN  gas  170000.0       manual   NaN        NaN         NaN
# 273862  8 cylinders  gas   45554.0    automatic   rwd      truck       white
# 53716   6 cylinders  gas  108000.0    automatic   4wd      sedan       black
# 255093          NaN  gas   72583.0    automatic   NaN      other       black
# 307733  4 cylinders  gas   42000.0    automatic   4wd        SUV         red
# 162804  6 cylinders  NaN   35230.0    automatic   fwd      sedan       brown
# 211558          NaN  gas   32200.0    automatic   NaN  hatchback         red
# 237374  6 cylinders  gas  268500.0       manual   rwd      coupe         red
# 168986          NaN  gas   97623.0    automatic   4wd     pickup        blue
# 366943  6 cylinders  gas  200000.0       manual   4wd        NaN         NaN
#
#        state        lat        long              posting_date
# 283109    nh  42.887400  -71.302000  2021-05-04T08:21:25-0400
# 273862    ny  40.468785  -74.281707  2021-04-23T13:30:07-0400
# 53716     ca  38.691000 -121.748800  2021-05-01T17:06:49-0700
# 255093    nj  40.923344  -74.143356  2021-04-25T17:13:01-0400
# 307733    ok  34.006100  -96.384700  2021-04-10T09:26:30-0500
# 162804    ia  41.207382  -96.023096  2021-04-19T12:20:44-0500
# 211558    mn  46.815216  -92.178109  2021-05-01T08:41:56-0500
# 237374    nc  36.212700  -79.989700  2021-04-23T15:22:23-0400
# 168986    ks  37.646221  -98.740903  2021-04-29T09:59:10-0500
# 366943    tx  26.133700  -97.644700  2021-04-15T17:17:29-0500

# %%
""" df.at[38697, "manufacturer"] = "bmw" """
# Out:
# ' df.at[38697, "manufacturer"] = "bmw" '

# %%
df["manufacturer"].value_counts()
# Out:
# ford               70985
# chevrolet          55064
# toyota             34202
# honda              21269
# nissan             19067
# jeep               19014
# ram                18342
# gmc                16785
# bmw                14699
# dodge              13707
# mercedes-benz      11817
# hyundai            10338
# subaru              9495
# volkswagen          9345
# kia                 8457
# lexus               8200
# audi                7573
# cadillac            6953
# chrysler            6031
# acura               5978
# buick               5501
# mazda               5427
# infiniti            4802
# lincoln             4220
# volvo               3374
# mitsubishi          3292
# mini                2376
# pontiac             2288
# rover               2113
# jaguar              1946
# porsche             1384
# mercury             1184
# saturn              1090
# alfa-romeo           897
# tesla                868
# fiat                 792
# harley-davidson      153
# ferrari               95
# datsun                63
# aston-martin          24
# land rover            21
# morgan                 3
# Name: manufacturer, dtype: int64

# %%
df["condition"].value_counts()
# Out:
# good         121456
# excellent    101467
# like new      21178
# fair           6769
# new            1305
# salvage         601
# Name: condition, dtype: int64

# %%
df["transmission"].value_counts()
# Out:
# automatic    336524
# other         62682
# manual        25118
# Name: transmission, dtype: int64

# %%
df["drive"].value_counts()
# Out:
# 4wd    131904
# fwd    105517
# rwd     58892
# Name: drive, dtype: int64

# %%
df["type"].value_counts()
# Out:
# sedan          87056
# SUV            77284
# pickup         43510
# truck          35279
# other          22110
# coupe          19204
# hatchback      16598
# wagon          10751
# van             8548
# convertible     7731
# mini-van        4825
# offroad          609
# bus              517
# Name: type, dtype: int64

# %%
#se convierte los prefijos de los estados a mayusculas.
df["state"] = df["state"].str.upper()
df["state"].value_counts()
# Out:
# CA    50614
# FL    28511
# TX    22945
# NY    19386
# OH    17696
# OR    17104
# MI    16900
# NC    15277
# WA    13861
# PA    13753
# WI    11398
# CO    11088
# TN    11066
# VA    10732
# IL    10387
# NJ     9742
# ID     8961
# AZ     8679
# IA     8632
# MA     8174
# MN     7716
# GA     7003
# OK     6792
# SC     6327
# MT     6294
# KS     6209
# IN     5704
# CT     5188
# AL     4955
# MD     4778
# NM     4425
# MO     4293
# KY     4149
# AR     4038
# AK     3474
# LA     3196
# NV     3194
# NH     2981
# DC     2970
# ME     2966
# HI     2964
# VT     2513
# RI     2320
# SD     1302
# UT     1150
# WV     1052
# NE     1036
# MS     1016
# DE      949
# WY      610
# ND      410
# Name: state, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         426880 non-null  int64
#  1   year          425675 non-null  float64
#  2   manufacturer  409234 non-null  object
#  3   model         421603 non-null  object
#  4   condition     252776 non-null  object
#  5   cylinders     249202 non-null  object
#  6   fuel          423867 non-null  object
#  7   odometer      422480 non-null  float64
#  8   transmission  424324 non-null  object
#  9   drive         296313 non-null  object
#  10  type          334022 non-null  object
#  11  paint_color   296677 non-null  object
#  12  state         426880 non-null  object
#  13  lat           420331 non-null  float64
#  14  long          420331 non-null  float64
#  15  posting_date  426812 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 52.1+ MB

# %% [markdown]
# ### Para e tratamiento de nulos, los voy a separar en 2 partes, la visualizacion y machine learning. Para la visualizacion voy a crear la variable desconocida, y eliminar el menor numero de datos.Para el modelo al ser la mayoria variables categoricas, voy a realizar primero el encoding de estas. Se realiza el encoding para poder aplicar el método KNN imputer de reemplazar los nulos por valores similiares al de sus vecinos mas parecidos.

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# price            0.000000
# year             0.282281
# manufacturer     4.133714
# model            1.236179
# condition       40.785232
# cylinders       41.622470
# fuel             0.705819
# odometer         1.030735
# transmission     0.598763
# drive           30.586347
# type            21.752717
# paint_color     30.501078
# state            0.000000
# lat              1.534155
# long             1.534155
# posting_date     0.015930
# dtype: float64

# %% [markdown]
# ### Al ser un set de datos de vehiculos,lo mas normal es que haya vehiculos repetidos.Usando esa ventaja, se sustituyen los valores nulos de algunas columnas, solo si coincide el modelo, por el valor que le corresponde.

# %%
df.head()
# Out:
#    price  year manufacturer model condition cylinders fuel  odometer  \
# 0   6000   NaN          NaN   NaN       NaN       NaN  NaN       NaN
# 1  11900   NaN          NaN   NaN       NaN       NaN  NaN       NaN
# 2  21000   NaN          NaN   NaN       NaN       NaN  NaN       NaN
# 3   1500   NaN          NaN   NaN       NaN       NaN  NaN       NaN
# 4   4900   NaN          NaN   NaN       NaN       NaN  NaN       NaN
#
#   transmission drive type paint_color state  lat  long posting_date
# 0          NaN   NaN  NaN         NaN    AZ  NaN   NaN          NaN
# 1          NaN   NaN  NaN         NaN    AR  NaN   NaN          NaN
# 2          NaN   NaN  NaN         NaN    FL  NaN   NaN          NaN
# 3          NaN   NaN  NaN         NaN    MA  NaN   NaN          NaN
# 4          NaN   NaN  NaN         NaN    NC  NaN   NaN          NaN

# %%
df2 = df.copy()
df2.head()
# Out:
#    price  year manufacturer model condition cylinders fuel  odometer  \
# 0   6000   NaN          NaN   NaN       NaN       NaN  NaN       NaN
# 1  11900   NaN          NaN   NaN       NaN       NaN  NaN       NaN
# 2  21000   NaN          NaN   NaN       NaN       NaN  NaN       NaN
# 3   1500   NaN          NaN   NaN       NaN       NaN  NaN       NaN
# 4   4900   NaN          NaN   NaN       NaN       NaN  NaN       NaN
#
#   transmission drive type paint_color state  lat  long posting_date
# 0          NaN   NaN  NaN         NaN    AZ  NaN   NaN          NaN
# 1          NaN   NaN  NaN         NaN    AR  NaN   NaN          NaN
# 2          NaN   NaN  NaN         NaN    FL  NaN   NaN          NaN
# 3          NaN   NaN  NaN         NaN    MA  NaN   NaN          NaN
# 4          NaN   NaN  NaN         NaN    NC  NaN   NaN          NaN

# %%
# En este caso, se rellenan los valores nulos de la columna manufacturer.
# Se crea un diccionario con los valores a reemplazar
reemplazos = dict(df.groupby('model')['manufacturer'].apply(lambda x: x.ffill().bfill()))

# Se usa el diccionario para reemplazar los nulos en la columna "manufacturer"
df['manufacturer'] = df['manufacturer'].fillna(reemplazos)

# %%
reemplazos
# Out:
# {27: 'gmc',
#  28: 'chevrolet',
#  29: 'chevrolet',
#  30: 'toyota',
#  31: 'ford',
#  32: 'gmc',
#  33: 'chevrolet',
#  34: 'toyota',
#  35: 'chevrolet',
#  36: 'chevrolet',
#  37: 'jeep',
#  38: 'jeep',
#  39: 'chevrolet',
#  40: 'chevrolet',
#  41: 'toyota',
#  42: 'chevrolet',
#  43: 'toyota',
#  44: 'ford',
#  45: 'nissan',
#  46: 'jeep',
#  47: 'ford',
#  48: 'toyota',
#  49: 'jeep',
#  50: 'ford',
#  51: 'ram',
#  52: 'mazda',
#  53: 'ford',
#  54: 'cadillac',
#  55: 'ford',
#  56: 'jeep',
#  57: 'ford',
#  58: 'gmc',
#  59: 'honda',
#  60: 'ram',
#  61: 'gmc',
#  62: 'ram',
#  63: 'ford',
#  64: 'chevrolet',
#  65: 'ford',
#  66: 'chevrolet',
#  67: 'toyota',
#  68: 'chevrolet',
#  69: 'chevrolet',
#  70: 'toyota',
#  71: 'chevrolet',
#  72: 'jeep',
#  73: 'dodge',
#  74: 'honda',
#  75: 'honda',
#  76: 'ford',
#  77: 'honda',
#  78: 'ford',
#  79: 'jeep',
#  80: 'toyota',
#  81: 'ford',
#  82: 'lexus',
#  83: 'jaguar',
#  84: 'buick',
#  85: 'lexus',
#  86: 'chrysler',
#  87: 'volvo',
#  88: 'volvo',
#  89: 'volvo',
#  90: 'volvo',
#  91: 'audi',
#  92: 'infiniti',
#  93: 'lincoln',
#  94: 'alfa-romeo',
#  95: 'subaru',
#  97: nan,
#  98: 'acura',
#  99: 'audi',
#  100: 'hyundai',
#  102: 'ram',
#  103: 'gmc',
#  104: 'gmc',
#  105: 'ford',
#  106: 'jeep',
#  107: 'jeep',
#  108: 'jeep',
#  109: 'jeep',
#  110: 'chrysler',
#  111: 'gmc',
#  112: 'lincoln',
#  113: 'gmc',
#  114: 'lincoln',
#  115: 'lexus',
#  116: 'lexus',
#  117: 'buick',
#  118: 'jaguar',
#  119: 'toyota',
#  120: 'mercedes-benz',
#  121: 'volvo',
#  122: nan,
#  123: 'volvo',
#  124: 'volvo',
#  125: 'volvo',
#  126: 'chevrolet',
#  127: 'chevrolet',
#  128: 'chevrolet',
#  129: 'infiniti',
#  130: 'alfa-romeo',
#  131: 'lincoln',
#  132: 'audi',
#  133: 'hyundai',
#  134: 'audi',
#  135: nan,
#  136: 'acura',
#  137: nan,
#  138: 'jeep',
#  139: 'jeep',
#  140: 'jeep',
#  141: 'toyota',
#  142: 'ram',
#  143: 'jeep',
#  144: 'jeep',
#  145: 'jeep',
#  146: 'jeep',
#  147: 'bmw',
#  148: 'chrysler',
#  149: 'mitsubishi',
#  150: 'nissan',
#  151: 'gmc',
#  152: 'gmc',
#  153: 'gmc',
#  154: 'lincoln',
#  155: nan,
#  156: 'lexus',
#  157: 'buick',
#  158: 'jaguar',
#  159: 'subaru',
#  160: 'acura',
#  161: 'volvo',
#  162: 'volvo',
#  163: 'volvo',
#  164: 'volvo',
#  165: 'lincoln',
#  166: 'alfa-romeo',
#  167: 'infiniti',
#  168: 'audi',
#  169: 'toyota',
#  170: 'toyota',
#  171: nan,
#  172: 'bmw',
#  173: 'ford',
#  174: 'volkswagen',
#  175: 'ford',
#  176: 'toyota',
#  177: 'ford',
#  178: 'honda',
#  179: 'mazda',
#  180: 'mazda',
#  181: 'porsche',
#  182: 'mazda',
#  183: 'lexus',
#  184: 'lexus',
#  185: 'toyota',
#  186: 'ford',
#  187: 'ford',
#  188: 'chevrolet',
#  189: 'nissan',
#  190: 'nissan',
#  191: 'nissan',
#  192: 'kia',
#  193: 'ford',
#  194: nan,
#  195: 'dodge',
#  196: 'ford',
#  197: 'ford',
#  198: 'ford',
#  199: 'toyota',
#  200: 'nissan',
#  201: 'nissan',
#  202: 'toyota',
#  203: 'buick',
#  204: 'gmc',
#  205: 'chevrolet',
#  206: 'honda',
#  207: 'ford',
#  208: 'chevrolet',
#  209: 'toyota',
#  210: 'mercedes-benz',
#  211: 'bmw',
#  212: 'kia',
#  213: 'chevrolet',
#  214: 'buick',
#  215: 'toyota',
#  216: 'hyundai',
#  217: 'chevrolet',
#  218: 'nissan',
#  219: 'bmw',
#  220: nan,
#  221: 'gmc',
#  222: 'gmc',
#  223: 'ford',
#  224: 'honda',
#  225: 'chevrolet',
#  226: 'chevrolet',
#  227: 'chevrolet',
#  228: 'ford',
#  229: 'ford',
#  230: 'gmc',
#  231: 'gmc',
#  232: 'mercedes-benz',
#  233: 'chrysler',
#  234: 'ford',
#  235: 'ford',
#  236: 'ford',
#  237: 'chevrolet',
#  238: 'infiniti',
#  239: 'chevrolet',
#  240: 'chevrolet',
#  241: 'jeep',
#  242: nan,
#  243: nan,
#  244: 'chevrolet',
#  245: 'mercedes-benz',
#  246: 'chevrolet',
#  247: 'toyota',
#  248: 'kia',
#  249: 'ford',
#  250: 'nissan',
#  251: 'chevrolet',
#  252: 'chevrolet',
#  253: 'kia',
#  254: 'nissan',
#  255: nan,
#  256: 'volkswagen',
#  257: 'porsche',
#  258: 'mercedes-benz',
#  259: 'mercedes-benz',
#  260: 'chevrolet',
#  261: 'cadillac',
#  262: 'ford',
#  263: 'nissan',
#  264: nan,
#  265: nan,
#  266: 'bmw',
#  267: 'honda',
#  268: 'mazda',
#  269: 'cadillac',
#  270: 'chevrolet',
#  271: 'chevrolet',
#  272: 'acura',
#  273: 'toyota',
#  274: 'nissan',
#  275: 'ram',
#  276: 'kia',
#  277: 'jeep',
#  278: 'toyota',
#  279: 'honda',
#  281: 'buick',
#  282: 'ford',
#  283: 'ford',
#  284: 'toyota',
#  285: 'jeep',
#  286: 'ram',
#  287: 'gmc',
#  288: 'ford',
#  289: 'chevrolet',
#  290: 'kia',
#  291: 'ford',
#  292: 'chevrolet',
#  293: 'buick',
#  294: 'dodge',
#  295: 'mercedes-benz',
#  296: 'nissan',
#  297: 'nissan',
#  298: 'nissan',
#  299: 'infiniti',
#  300: 'nissan',
#  301: 'subaru',
#  302: 'ram',
#  303: 'gmc',
#  304: 'mercedes-benz',
#  305: 'mercedes-benz',
#  306: 'chevrolet',
#  307: 'jeep',
#  309: 'chevrolet',
#  310: 'toyota',
#  311: 'ford',
#  312: 'kia',
#  313: 'volvo',
#  314: 'jeep',
#  315: 'toyota',
#  316: 'chevrolet',
#  317: 'buick',
#  318: 'dodge',
#  319: 'toyota',
#  320: 'ford',
#  321: 'honda',
#  322: 'buick',
#  323: 'hyundai',
#  324: 'ford',
#  325: 'nissan',
#  326: 'hyundai',
#  327: 'kia',
#  328: 'infiniti',
#  329: 'ram',
#  330: 'buick',
#  331: 'gmc',
#  332: 'toyota',
#  333: 'jeep',
#  334: 'kia',
#  335: 'ford',
#  336: 'jeep',
#  337: 'ford',
#  338: 'mercedes-benz',
#  339: 'toyota',
#  340: 'hyundai',
#  341: 'chrysler',
#  342: 'chevrolet',
#  343: 'nissan',
#  344: 'toyota',
#  345: nan,
#  346: 'ferrari',
#  347: 'mini',
#  348: 'toyota',
#  349: 'toyota',
#  350: nan,
#  351: 'ford',
#  352: 'ford',
#  353: 'pontiac',
#  354: 'acura',
#  355: 'mercedes-benz',
#  356: 'dodge',
#  357: 'nissan',
#  358: 'kia',
#  359: 'ford',
#  360: 'ford',
#  361: 'chevrolet',
#  362: 'chevrolet',
#  363: 'ram',
#  364: 'lexus',
#  365: 'chevrolet',
#  366: 'audi',
#  367: 'chevrolet',
#  368: 'chevrolet',
#  369: 'dodge',
#  370: 'mitsubishi',
#  371: 'chevrolet',
#  372: 'honda',
#  373: 'toyota',
#  374: 'toyota',
#  375: 'ford',
#  376: 'nissan',
#  377: 'toyota',
#  378: 'ford',
#  379: 'toyota',
#  380: 'ford',
#  381: 'toyota',
#  382: 'infiniti',
#  383: 'nissan',
#  384: 'bmw',
#  385: 'chevrolet',
#  386: nan,
#  387: 'nissan',
#  388: 'nissan',
#  389: 'nissan',
#  390: 'toyota',
#  391: 'dodge',
#  392: 'ram',
#  393: 'ford',
#  394: 'volkswagen',
#  395: 'ford',
#  396: 'ford',
#  397: 'volkswagen',
#  398: 'ford',
#  399: 'chevrolet',
#  400: 'jeep',
#  401: nan,
#  402: nan,
#  403: 'toyota',
#  404: 'nissan',
#  405: 'subaru',
#  406: 'nissan',
#  407: 'buick',
#  408: 'toyota',
#  409: 'dodge',
#  410: 'toyota',
#  411: 'acura',
#  412: 'chevrolet',
#  413: 'chevrolet',
#  415: 'infiniti',
#  416: 'toyota',
#  417: 'nissan',
#  418: 'jeep',
#  419: 'chevrolet',
#  420: 'toyota',
#  421: 'chevrolet',
#  422: 'buick',
#  423: 'ram',
#  424: 'volkswagen',
#  425: 'hyundai',
#  426: 'subaru',
#  427: 'chevrolet',
#  428: 'dodge',
#  429: 'chrysler',
#  430: 'ford',
#  431: 'nissan',
#  432: 'volkswagen',
#  433: 'chevrolet',
#  434: 'mercedes-benz',
#  435: nan,
#  436: 'nissan',
#  437: 'ford',
#  438: nan,
#  439: 'chevrolet',
#  440: 'kia',
#  441: 'ford',
#  442: 'nissan',
#  443: 'infiniti',
#  444: 'toyota',
#  445: 'toyota',
#  446: 'mercedes-benz',
#  447: 'gmc',
#  448: nan,
#  449: 'ford',
#  450: 'chevrolet',
#  451: nan,
#  452: 'mercedes-benz',
#  453: 'pontiac',
#  454: 'mercedes-benz',
#  456: 'infiniti',
#  457: 'ford',
#  458: 'pontiac',
#  459: 'chevrolet',
#  460: 'nissan',
#  461: 'chevrolet',
#  462: 'pontiac',
#  463: 'dodge',
#  464: 'cadillac',
#  465: 'gmc',
#  466: 'ford',
#  467: nan,
#  468: 'toyota',
#  469: 'toyota',
#  470: 'kia',
#  471: 'toyota',
#  472: 'toyota',
#  473: 'acura',
#  474: 'nissan',
#  475: nan,
#  476: nan,
#  477: 'ford',
#  478: 'toyota',
#  479: 'gmc',
#  480: 'lexus',
#  481: 'gmc',
#  482: 'gmc',
#  483: 'lincoln',
#  484: 'ford',
#  485: 'bmw',
#  486: 'bmw',
#  487: 'honda',
#  488: 'buick',
#  489: 'chevrolet',
#  490: 'honda',
#  491: 'honda',
#  492: nan,
#  493: 'chevrolet',
#  494: nan,
#  495: 'infiniti',
#  496: 'lexus',
#  497: 'infiniti',
#  498: 'toyota',
#  499: 'toyota',
#  500: 'lexus',
#  501: 'ford',
#  502: 'ford',
#  503: 'ford',
#  504: 'gmc',
#  505: 'mazda',
#  506: 'ford',
#  507: 'ford',
#  508: 'ford',
#  509: 'jeep',
#  510: 'chevrolet',
#  511: 'jeep',
#  512: 'chrysler',
#  513: 'nissan',
#  514: 'ford',
#  515: 'ford',
#  516: 'ford',
#  517: 'nissan',
#  518: 'ford',
#  519: 'ford',
#  520: 'ford',
#  521: 'ford',
#  522: 'chevrolet',
#  523: 'chevrolet',
#  524: 'chevrolet',
#  525: 'ford',
#  526: 'chevrolet',
#  527: 'ford',
#  528: 'ford',
#  529: 'jaguar',
#  530: 'honda',
#  531: 'gmc',
#  532: 'ford',
#  533: 'jeep',
#  534: 'toyota',
#  535: 'ram',
#  536: nan,
#  537: 'ford',
#  538: 'chevrolet',
#  539: 'ram',
#  540: 'hyundai',
#  541: 'jeep',
#  542: 'ford',
#  543: 'honda',
#  544: 'fiat',
#  545: 'mercedes-benz',
#  546: 'nissan',
#  547: 'ford',
#  548: 'toyota',
#  549: 'ford',
#  550: 'ford',
#  551: 'ford',
#  552: 'dodge',
#  553: 'ford',
#  554: 'volvo',
#  555: 'ford',
#  556: 'gmc',
#  557: 'ford',
#  558: 'chrysler',
#  559: 'infiniti',
#  560: 'kia',
#  561: 'ford',
#  562: 'ram',
#  563: 'ford',
#  564: 'bmw',
#  565: 'dodge',
#  566: 'gmc',
#  567: 'gmc',
#  568: 'kia',
#  569: 'chevrolet',
#  570: 'mercedes-benz',
#  571: 'gmc',
#  572: 'ram',
#  573: 'ram',
#  574: 'gmc',
#  575: 'buick',
#  576: 'acura',
#  577: 'ford',
#  578: nan,
#  579: nan,
#  580: 'toyota',
#  581: 'mazda',
#  582: 'toyota',
#  583: 'hyundai',
#  584: 'buick',
#  585: 'chevrolet',
#  586: 'cadillac',
#  587: 'acura',
#  588: 'chevrolet',
#  589: 'honda',
#  590: 'chevrolet',
#  591: nan,
#  592: 'mercedes-benz',
#  593: 'hyundai',
#  594: 'kia',
#  595: 'cadillac',
#  596: 'hyundai',
#  597: 'nissan',
#  598: 'rover',
#  599: 'chevrolet',
#  600: 'lexus',
#  601: nan,
#  602: 'lincoln',
#  603: 'honda',
#  604: 'chevrolet',
#  605: 'honda',
#  606: 'nissan',
#  607: 'chevrolet',
#  608: 'chevrolet',
#  609: 'chevrolet',
#  610: 'jeep',
#  611: 'jeep',
#  612: 'mazda',
#  613: 'chevrolet',
#  614: 'ram',
#  615: 'ram',
#  616: 'ford',
#  617: 'audi',
#  618: 'chevrolet',
#  619: 'ford',
#  620: 'chevrolet',
#  621: 'ram',
#  622: 'chevrolet',
#  623: 'ford',
#  624: 'chevrolet',
#  625: 'ram',
#  626: 'honda',
#  627: 'gmc',
#  628: nan,
#  629: 'toyota',
#  630: 'toyota',
#  631: 'mercedes-benz',
#  632: nan,
#  633: 'chevrolet',
#  634: 'chevrolet',
#  635: 'toyota',
#  636: 'gmc',
#  637: 'chevrolet',
#  638: 'nissan',
#  639: 'nissan',
#  640: 'nissan',
#  641: 'ram',
#  642: 'chevrolet',
#  643: nan,
#  644: 'lincoln',
#  645: 'ford',
#  646: 'chevrolet',
#  647: 'toyota',
#  648: 'chevrolet',
#  649: 'ford',
#  650: 'hyundai',
#  651: 'ford',
#  652: 'jeep',
#  653: 'toyota',
#  654: 'chrysler',
#  655: 'chevrolet',
#  656: 'mercedes-benz',
#  657: 'toyota',
#  658: 'toyota',
#  659: 'nissan',
#  660: 'nissan',
#  661: 'chevrolet',
#  662: 'dodge',
#  663: 'ford',
#  664: 'chevrolet',
#  665: 'jeep',
#  666: 'audi',
#  667: 'chevrolet',
#  668: 'volvo',
#  669: 'hyundai',
#  670: 'chevrolet',
#  671: 'gmc',
#  672: 'mazda',
#  673: 'infiniti',
#  674: 'nissan',
#  675: 'hyundai',
#  676: 'hyundai',
#  677: 'jeep',
#  678: nan,
#  679: 'chevrolet',
#  680: 'buick',
#  681: 'infiniti',
#  682: 'ford',
#  683: 'toyota',
#  684: 'hyundai',
#  685: 'mini',
#  686: 'buick',
#  687: 'nissan',
#  688: 'honda',
#  689: 'hyundai',
#  690: 'nissan',
#  691: 'ford',
#  692: 'kia',
#  693: 'pontiac',
#  694: 'kia',
#  695: 'ford',
#  696: nan,
#  697: 'honda',
#  698: 'chrysler',
#  699: 'ford',
#  700: 'lexus',
#  701: 'kia',
#  702: 'kia',
#  703: 'bmw',
#  704: 'chevrolet',
#  705: 'ford',
#  706: 'cadillac',
#  707: 'ford',
#  708: 'ram',
#  709: 'ford',
#  710: nan,
#  711: 'ford',
#  712: 'rover',
#  713: nan,
#  714: nan,
#  715: nan,
#  716: 'gmc',
#  717: 'mercedes-benz',
#  718: 'ford',
#  719: 'kia',
#  720: 'infiniti',
#  721: 'toyota',
#  722: 'chevrolet',
#  723: 'jeep',
#  724: 'nissan',
#  725: 'dodge',
#  726: 'lexus',
#  727: 'ford',
#  728: nan,
#  730: 'ram',
#  731: nan,
#  732: 'jeep',
#  733: 'lexus',
#  734: 'chevrolet',
#  735: 'ford',
#  736: 'chevrolet',
#  737: 'ford',
#  738: 'gmc',
#  739: 'ford',
#  740: 'ford',
#  741: 'ford',
#  742: 'ford',
#  743: 'ford',
#  744: 'ford',
#  745: nan,
#  746: 'infiniti',
#  747: 'ram',
#  748: 'dodge',
#  749: 'kia',
#  750: 'chevrolet',
#  751: 'jeep',
#  752: 'ford',
#  753: 'nissan',
#  754: 'nissan',
#  755: 'nissan',
#  756: 'mercedes-benz',
#  757: 'kia',
#  758: 'jeep',
#  759: 'hyundai',
#  760: 'gmc',
#  761: 'ford',
#  762: 'ram',
#  763: 'cadillac',
#  764: 'honda',
#  765: 'chevrolet',
#  766: 'ram',
#  767: 'ford',
#  768: 'nissan',
#  769: 'honda',
#  770: 'dodge',
#  771: 'ford',
#  772: 'jeep',
#  773: 'chevrolet',
#  774: 'ford',
#  775: nan,
#  776: 'ford',
#  777: 'chevrolet',
#  778: 'ford',
#  779: 'mazda',
#  780: 'jeep',
#  781: 'ram',
#  782: 'ram',
#  783: 'ford',
#  784: 'chevrolet',
#  785: 'acura',
#  786: 'chevrolet',
#  787: nan,
#  788: 'ford',
#  789: 'chevrolet',
#  790: 'ford',
#  791: 'ford',
#  792: 'gmc',
#  793: 'chevrolet',
#  794: nan,
#  795: 'chevrolet',
#  796: 'ford',
#  797: 'ford',
#  798: nan,
#  799: 'chevrolet',
#  800: 'chevrolet',
#  801: 'ford',
#  802: 'ford',
#  803: 'ford',
#  804: 'mitsubishi',
#  805: 'chevrolet',
#  806: 'ford',
#  807: nan,
#  808: 'chevrolet',
#  809: 'mitsubishi',
#  810: 'gmc',
#  811: 'mitsubishi',
#  812: 'ford',
#  813: 'ford',
#  814: 'ford',
#  815: nan,
#  816: 'ram',
#  817: 'ford',
#  818: 'ford',
#  819: 'ford',
#  820: 'ram',
#  821: 'ford',
#  822: nan,
#  823: 'ford',
#  824: nan,
#  825: 'ford',
#  826: 'ram',
#  827: 'chevrolet',
#  828: 'ford',
#  829: 'ford',
#  830: 'ford',
#  831: 'ford',
#  832: nan,
#  833: 'toyota',
#  834: nan,
#  835: 'mitsubishi',
#  836: nan,
#  837: 'ford',
#  838: nan,
#  839: 'ford',
#  840: 'chevrolet',
#  841: 'chevrolet',
#  842: 'gmc',
#  843: 'ford',
#  844: 'ford',
#  845: 'ford',
#  846: 'chevrolet',
#  847: 'chevrolet',
#  848: nan,
#  849: nan,
#  850: 'gmc',
#  851: 'chevrolet',
#  852: 'chevrolet',
#  853: 'ford',
#  854: nan,
#  855: 'ford',
#  856: 'chevrolet',
#  857: 'ford',
#  858: 'ford',
#  859: 'mercedes-benz',
#  860: 'gmc',
#  861: 'kia',
#  862: 'ford',
#  863: nan,
#  864: 'jeep',
#  865: 'jeep',
#  866: 'jeep',
#  867: 'bmw',
#  868: nan,
#  869: 'dodge',
#  870: 'ford',
#  871: 'jeep',
#  872: 'infiniti',
#  873: 'mercedes-benz',
#  874: 'lexus',
#  875: 'jeep',
#  876: 'toyota',
#  877: 'lincoln',
#  878: 'nissan',
#  879: 'mitsubishi',
#  880: 'ram',
#  881: 'ford',
#  882: 'chrysler',
#  883: 'chevrolet',
#  884: 'nissan',
#  885: 'ford',
#  886: 'ford',
#  887: 'chevrolet',
#  888: 'ford',
#  889: 'jeep',
#  890: 'chevrolet',
#  891: 'toyota',
#  892: 'nissan',
#  893: 'mini',
#  894: 'kia',
#  895: 'jeep',
#  896: nan,
#  897: 'jeep',
#  898: 'lexus',
#  899: 'jeep',
#  900: 'infiniti',
#  901: 'honda',
#  902: 'ford',
#  903: nan,
#  904: 'ford',
#  905: 'ford',
#  906: 'ford',
#  907: 'ford',
#  908: 'ford',
#  909: 'ford',
#  910: 'infiniti',
#  911: 'dodge',
#  912: 'ford',
#  913: 'buick',
#  914: 'ford',
#  915: 'toyota',
#  916: 'chevrolet',
#  917: 'lexus',
#  918: 'mitsubishi',
#  919: nan,
#  920: 'cadillac',
#  921: 'honda',
#  922: 'toyota',
#  923: 'toyota',
#  924: 'lexus',
#  925: 'cadillac',
#  926: 'nissan',
#  927: 'lexus',
#  928: 'honda',
#  929: 'toyota',
#  930: 'lexus',
#  931: 'ford',
#  932: 'lexus',
#  933: nan,
#  934: 'chevrolet',
#  935: 'hyundai',
#  936: 'honda',
#  937: 'gmc',
#  938: 'ford',
#  939: 'chevrolet',
#  940: 'chrysler',
#  941: 'cadillac',
#  942: 'buick',
#  943: 'acura',
#  944: 'buick',
#  945: 'toyota',
#  946: 'ford',
#  947: 'nissan',
#  948: 'bmw',
#  949: 'ford',
#  950: 'cadillac',
#  951: 'dodge',
#  952: 'bmw',
#  953: 'nissan',
#  954: 'kia',
#  955: nan,
#  956: 'acura',
#  957: 'buick',
#  958: 'hyundai',
#  959: 'chevrolet',
#  960: 'buick',
#  961: 'acura',
#  962: 'chevrolet',
#  963: 'acura',
#  964: nan,
#  965: 'acura',
#  966: 'nissan',
#  967: 'toyota',
#  968: 'nissan',
#  969: 'chrysler',
#  970: 'jeep',
#  971: 'acura',
#  972: 'infiniti',
#  973: 'toyota',
#  974: 'ford',
#  975: 'nissan',
#  976: 'chevrolet',
#  977: 'ford',
#  978: 'toyota',
#  979: 'ford',
#  980: 'mercedes-benz',
#  981: 'nissan',
#  982: 'honda',
#  983: 'mazda',
#  984: 'jaguar',
#  985: 'chevrolet',
#  986: 'kia',
#  987: 'acura',
#  988: 'bmw',
#  990: nan,
#  991: 'ford',
#  992: 'chevrolet',
#  993: 'alfa-romeo',
#  994: 'hyundai',
#  995: 'toyota',
#  996: 'hyundai',
#  997: 'bmw',
#  998: nan,
#  999: 'cadillac',
#  1000: 'kia',
#  1001: 'toyota',
#  1002: 'honda',
#  1003: 'nissan',
#  1004: 'jeep',
#  1005: 'mercedes-benz',
#  1006: nan,
#  1007: 'nissan',
#  1008: 'tesla',
#  1009: 'cadillac',
#  1010: 'toyota',
#  1011: 'ford',
#  1012: nan,
#  1013: 'nissan',
#  1014: 'nissan',
#  1015: 'lexus',
#  1016: nan,
#  1017: 'chevrolet',
#  1018: 'ford',
#  1019: 'mazda',
#  1020: 'ford',
#  1021: 'hyundai',
#  1022: 'toyota',
#  1023: 'volvo',
#  1024: nan,
#  1025: 'jeep',
#  1026: 'nissan',
#  1027: 'kia',
#  1028: 'ford',
#  1029: 'nissan',
#  1030: 'jeep',
#  1031: 'buick',
#  1032: 'audi',
#  1033: 'mercedes-benz',
#  1034: 'bmw',
#  ...}

# %%
# Se rellenan los valores nulos de la columna cylinders.
# Se crea un diccionario con los valores a reemplazar
reemplazos = dict(df.groupby('model')['cylinders'].apply(lambda x: x.ffill().bfill()))

# Se usa el diccionario para reemplazar los nulos en la columna "manufacturer"
df['cylinders'] = df['cylinders'].fillna(reemplazos)

# %%
""" Al realizar esto, se han sustituido un 32% de los valores nulos que habia"""
df.isnull().sum()/df.shape[0]*100
# Out:
# price            0.000000
# year             0.282281
# manufacturer     3.953804
# model            1.236179
# condition       40.785232
# cylinders        9.525628
# fuel             0.705819
# odometer         1.030735
# transmission     0.598763
# drive           30.586347
# type            21.752717
# paint_color     30.501078
# state            0.000000
# lat              1.534155
# long             1.534155
# posting_date     0.015930
# dtype: float64

# %%
# Se rellenan los valores nulos de la columna drive.
# Se crea un diccionario con los valores a reemplazar
reemplazos = dict(df.groupby('model')['drive'].apply(lambda x: x.ffill().bfill()))

# Se usa el diccionario para reemplazar los nulos en la columna "manufacturer"
df['drive'] = df['drive'].fillna(reemplazos)

# %%
"""Se ha reemplazado un 24% de los valores nulos, por sus valores correspondientes, teniendo en cuenta el modelo. """
df.isnull().sum()/df.shape[0]*100
# Out:
# price            0.000000
# year             0.282281
# manufacturer     3.953804
# model            1.236179
# condition       40.785232
# cylinders        9.525628
# fuel             0.705819
# odometer         1.030735
# transmission     0.598763
# drive            6.083443
# type            21.752717
# paint_color     30.501078
# state            0.000000
# lat              1.534155
# long             1.534155
# posting_date     0.015930
# dtype: float64

# %%
# Se rellenan los valores nulos de la columna type.
# Se crea un diccionario con los valores a reemplazar
reemplazos = dict(df.groupby('model')['type'].apply(lambda x: x.ffill().bfill()))

# Se usa el diccionario para reemplazar los nulos en la columna "manufacturer"
df['type'] = df['type'].fillna(reemplazos)

# %%
"""Se ha reemplazado un 19% de los valores nulos"""
df.isnull().sum()/df.shape[0]*100
# Out:
# price            0.000000
# year             0.282281
# manufacturer     3.953804
# model            1.236179
# condition       40.785232
# cylinders        9.525628
# fuel             0.705819
# odometer         1.030735
# transmission     0.598763
# drive            6.083443
# type             2.954226
# paint_color     30.501078
# state            0.000000
# lat              1.534155
# long             1.534155
# posting_date     0.015930
# dtype: float64

# %%
# Se rellenan los valores nulos de la columna paint_color.
# Se crea un diccionario con los valores a reemplazar
reemplazos = dict(df.groupby('model')['paint_color'].apply(lambda x: x.ffill().bfill()))

# Se usa el diccionario para reemplazar los nulos en la columna "manufacturer"
df['paint_color'] = df['paint_color'].fillna(reemplazos)

# %%
# Se rellenan los valores nulos de la columna lat, en este caso la referencia es el estado.
# Se crea un diccionario con los valores a reemplazar
reemplazos = dict(df.groupby('state')['lat'].apply(lambda x: x.ffill().bfill()))

# Se usa el diccionario para reemplazar los nulos en la columna "manufacturer"
df['lat'] = df['lat'].fillna(reemplazos)

# %%
# Se rellenan los valores nulos de la columna long, en este caso la referencia es el estado.
# Se crea un diccionario con los valores a reemplazar
reemplazos = dict(df.groupby('state')['long'].apply(lambda x: x.ffill().bfill()))

# Se usa el diccionario para reemplazar los nulos en la columna "manufacturer"
df['long'] = df['long'].fillna(reemplazos)

# %%
# Se rellenan los valores nulos de la columna fuel.
# Se crea un diccionario con los valores a reemplazar
reemplazos = dict(df.groupby('model')['fuel'].apply(lambda x: x.ffill().bfill()))

# Se usa el diccionario para reemplazar los nulos en la columna "manufacturer"
df['fuel'] = df['fuel'].fillna(reemplazos)

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# price            0.000000
# year             0.282281
# manufacturer     3.953804
# model            1.236179
# condition       40.785232
# cylinders        9.525628
# fuel             0.371533
# odometer         1.030735
# transmission     0.598763
# drive            6.083443
# type             2.954226
# paint_color      4.675319
# state            0.000000
# lat              0.000000
# long             0.000000
# posting_date     0.015930
# dtype: float64

# %%
#Se elimina la palabra "cylinders" de la columna, dejandola asi solo un numero como valor.
df["cylinders"] = df["cylinders"].str.split(' ').str[0]

# %% [markdown]
# ### Después de aplicar este método, hay un set de datos bastante mas limpio. Ahora se prodece a eliminar las filas que tengan mas de 4 valores nulos, ya que contienen poca información útil.

# %%
""" Elimino los valores que tengas mas de 5 valores nulos en sus datos
el parametro tresh filtra y elimina las filas con el minimo de valores correctos, tenemos que restarle los nulos maximos que queramos
    """
df2=df.copy()
df2.dropna(thresh=df.shape[1]- 5, inplace= True)
df2.isnull().sum()/df2.shape[0]*100
# Out:
# price            0.000000
# year             0.265484
# manufacturer     3.571412
# model            0.918221
# condition       40.351949
# cylinders        8.859149
# fuel             0.335572
# odometer         0.997749
# transmission     0.563535
# drive            5.391572
# type             2.256970
# paint_color      3.977780
# state            0.000000
# lat              0.000000
# long             0.000000
# posting_date     0.000000
# dtype: float64

# %%
print(df2.shape, df.shape)
# Out:
# (423754, 16) (426880, 16)

# %% [markdown]
# ### De esta manera se han eliminado un 0.1% de los datos para su visualización, dejando una muestra significativa para su estudio.
#
# ### El resto de los nulos se sustituiran por el valor "desconocido".
#
# ### La variable condición, no se puede sustituir por valores similares para su visualización, ya que seria "inventarse" los datos. Para el modelo predictivo si se puede hacer esa sustitución.

# %%
df2.fillna("desconocido",inplace=True)

# %%
df2.isnull().sum()/df2.shape[0]*100
# Out:
# price           0.0
# year            0.0
# manufacturer    0.0
# model           0.0
# condition       0.0
# cylinders       0.0
# fuel            0.0
# odometer        0.0
# transmission    0.0
# drive           0.0
# type            0.0
# paint_color     0.0
# state           0.0
# lat             0.0
# long            0.0
# posting_date    0.0
# dtype: float64

# %%
df2.replace(to_replace="other",value="desconocido", inplace=True)

# %%
df2.head()
# Out:
#     price    year manufacturer                     model  condition cylinders  \
# 27  33590  2014.0          gmc  sierra 1500 crew cab slt       good         8
# 28  22590  2010.0    chevrolet            silverado 1500       good         8
# 29  39590  2020.0    chevrolet       silverado 1500 crew       good         8
# 30  30990  2017.0       toyota      tundra double cab sr       good         8
# 31  15000  2013.0         ford                 f-150 xlt  excellent         6
#
#    fuel  odometer transmission drive    type paint_color state     lat  \
# 27  gas   57923.0  desconocido   4wd  pickup       white    AL  32.590
# 28  gas   71229.0  desconocido   4wd  pickup        blue    AL  32.590
# 29  gas   19160.0  desconocido   4wd  pickup         red    AL  32.590
# 30  gas   41124.0  desconocido   4wd  pickup         red    AL  32.590
# 31  gas  128000.0    automatic   rwd   truck       black    AL  32.592
#
#        long              posting_date
# 27 -85.4800  2021-05-04T12:31:18-0500
# 28 -85.4800  2021-05-04T12:31:08-0500
# 29 -85.4800  2021-05-04T12:31:25-0500
# 30 -85.4800  2021-05-04T10:41:31-0500
# 31 -85.5189  2021-05-03T14:02:03-0500

# %%
#Se elimina esta columna porque todos los anuncios son en el mes de abril y mayo.
df2.drop("posting_date", axis = 1, inplace=True)

# %% [markdown]
# ### Ahora toca limpiar la columna de modelo, cada fabricante tiene sus modelos y estos escritos de manera distinta, asi hay que mirarlos para corregirlos.

# %%
marcas = df2["manufacturer"].unique().tolist()
#43 marcas

# %%
def formato_texto(texto):
    # Reemplazar los guiones por espacios vacíos
    texto = texto.replace("-", " ")
    
    # Convertir el texto a título (primera letra de cada palabra en mayúscula)
    texto = texto.title()
    
    # Reemplazar los espacios por guiones bajos
    texto = texto.replace(" ", "_")
    
    # Devolver el texto formateado
    return texto

# %%
df2["manufacturer"] = df2["manufacturer"].apply(formato_texto)

# %%
df2["manufacturer"].value_counts()
# Out:
# Ford               70813
# Chevrolet          54897
# Toyota             34372
# Honda              21219
# Nissan             19032
# Jeep               19001
# Ram                18251
# Gmc                16730
# Desconocido        15134
# Bmw                14693
# Dodge              13651
# Mercedes_Benz      11800
# Hyundai            10327
# Subaru              9484
# Volkswagen          9324
# Kia                 8444
# Lexus               8182
# Audi                7569
# Cadillac            6926
# Chrysler            6035
# Acura               5965
# Buick               5495
# Mazda               5446
# Infiniti            4796
# Lincoln             4204
# Volvo               3311
# Mitsubishi          3289
# Mini                2374
# Pontiac             2280
# Rover               2141
# Jaguar              1939
# Porsche             1379
# Mercury             1183
# Saturn              1085
# Alfa_Romeo           897
# Tesla                867
# Fiat                 858
# Harley_Davidson      151
# Ferrari               95
# Datsun                68
# Aston_Martin          24
# Land_Rover            21
# Morgan                 2
# Name: manufacturer, dtype: int64

# %% [markdown]
# #### gmc

# %%
gmc = df2[df2["manufacturer"] == "Gmc"]
# Parece que en este fabricante el modelo es la primera palabra y lo siguiente es descripcion del modelo, asique solo interesa la primera
#gmc.sample(20)

# %% [markdown]
# #### Vemos los valores unicos de cada modelo para plantear el problema.

# %% [markdown]
# #### Con ayuda de chatGPT generamos una lista de todos los modelos de la marca gmc:
# ####   models = ['Canyon', 'Sierra 1500', 'Sierra 2500HD', 'Sierra 3500HD', 'Sierra Denali', 'Sierra AT4', 'Acadia', 'Terrain', 'Yukon', 'Yukon XL', 'Yukon Denali', "Jimmy", "Safari","Suburban",'Savana', "Brigadier", "Envoy","Graphyte", "Granite", "Sonoma","Syclone", "TopKick","Vandura",'TopKick C4500', 'TopKick C5500', 'TopKick C6500', 'TopKick C7500', "Tracker","Typhoon"]

# %%
"""## Con el metodo Levenshtein, teniendo la lista de modelos reales nos devuelve, transformados a los mas
## parecidos de la lista de modelos reales.

def find_closest_model(input_model):
    models = ['Canyon', 'Sierra 1500', 'Sierra 2500HD', 'Sierra 3500HD', 'Sierra Denali', 'Sierra AT4', 
              'Acadia', 'Terrain', 'Yukon', 'Yukon XL', 'Yukon Denali', "Jimmy", "Safari","Suburban",
              'Savana', "Brigadier", "Envoy","Graphyte", "Granite", "Sonoma","Syclone", "TopKick","Vandura",
              'TopKick C4500', 'TopKick C5500', 'TopKick C6500', 'TopKick C7500', "Tracker","Typhoon"]
    closest_match = min(models, key=lambda x: distance(x.lower(), input_model.lower()))
    return closest_match


# aplicar la función a la columna 'model' y guardar el resultado en una nueva columna 'modelo'
gmc['model'] = gmc['model'].apply(find_closest_model)"""
# Out:
# '## Con el metodo Levenshtein, teniendo la lista de modelos reales nos devuelve, transformados a los mas\n## parecidos de la lista de modelos reales.\n\ndef find_closest_model(input_model):\n    models = [\'Canyon\', \'Sierra 1500\', \'Sierra 2500HD\', \'Sierra 3500HD\', \'Sierra Denali\', \'Sierra AT4\', \n              \'Acadia\', \'Terrain\', \'Yukon\', \'Yukon XL\', \'Yukon Denali\', "Jimmy", "Safari","Suburban",\n              \'Savana\', "Brigadier", "Envoy","Graphyte", "Granite", "Sonoma","Syclone", "TopKick","Vandura",\n              \'TopKick C4500\', \'TopKick C5500\', \'TopKick C6500\', \'TopKick C7500\', "Tracker","Typhoon"]\n    closest_match = min(models, key=lambda x: distance(x.lower(), input_model.lower()))\n    return closest_match\n\n\n# aplicar la función a la columna \'model\' y guardar el resultado en una nueva columna \'modelo\'\ngmc[\'model\'] = gmc[\'model\'].apply(find_closest_model)'

# %%
gmc["model"].value_counts()
# Out:
# sierra 1500                1657
# sierra                     1282
# acadia                      925
# sierra 2500hd               895
# yukon                       884
#                            ...
# sierra sle 2500hd             1
# terrian sle2                  1
# sierra extended cab 4x4       1
# 3500 hd sl                    1
# sevana (custom)               1
# Name: model, Length: 1173, dtype: int64

# %% [markdown]
# ### Añadimos estos valores al set de datos original(df2)

# %%
df2["model"][df2["manufacturer"]== "gmc"] = gmc["model"]

# %% [markdown]
# ## Se hace lo mismo con el resto de marcas

# %% [markdown]
# ### Se definen las listas de modelos segun las marcas.

# %%
dicc_marcas = { "Gmc" : ['Canyon', 'Sierra 1500', 'Sierra 2500HD', 'Sierra 3500HD', 'Sierra Denali', 'Sierra AT4', 'Acadia', 'Terrain', 'Yukon', 'Yukon XL', 'Yukon Denali', "Jimmy", "Safari","Suburban",'Savana', "Brigadier", "Envoy","Graphyte", "Granite", "Sonoma","Syclone", "TopKick","Vandura",'TopKick C4500', 'TopKick C5500', 'TopKick C6500', 'TopKick C7500', "Tracker","Typhoon"]
    ,"Chevrolet" : ["Camaro","Caprice","Cavalier","Chevelle","Cobalt","Colorado","Corvette","Cruze","El Camino","Equinox","Express","HHR","Impala","Malibu","Monte Carlo","Silverado","Sonic","Spark","Suburban","Tahoe","Tracker","Trailblazer","Traverse"]

,"Toyota" : ["4Runner","Avalon", "Camry","Celica","Corolla","Echo","FJ Cruiser","Highlander","Land Cruiser","Matrix","MR2","Prius","RAV4","Sequoia","Sienna","Supra","Tacoma","Tundra","Venza","Yaris"]

,"Ford" : ["Aerostar","Bronco","Crown Victoria","Edge","Escape","Escort","Excursion","Expedition","Explorer","F-150","F-250","F-350","Festiva","Fiesta","Five Hundred","Flex","Focus","Fusion","Galaxie","Mustang","Probe","Ranger","Taurus","Tempo","Thunderbird","Transit","Windstar"]

,"Jeep" : ["Cherokee","Commander","Compass","Gladiator","Grand Cherokee","Liberty","Patriot","Renegade","Wrangler"]

,"Nissan" : ["240SX","300ZX","350Z","Altima","Armada","Cube","Frontier","GT-R","Juke","Leaf","Maxima","Murano","NV","Pajero","Pathfinder","Quest","Rogue","Sentra","Stanza","Titan","Versa","Xterra" ]

,"Ram" : ["1500","2500","3500","Cargo Van","ProMaster"]

,"Mazda" : ["323","626","B-Series","CX-3","CX-5","CX-7","CX-9","Miata","MPV","MX-3","MX-5","Navajo","Protege","RX-7","RX-8","Tribute" ]

,"Cadillac" : ["ATS","CT6","CTS","DeVille","DTS","Eldorado","Escalade","Fleetwood","Seville","SRX","STS","XLR" ]

,"Honda" : ["Accord","Civic","Clarity","CR-V","CR-X","Crosstour","Element","Fit","HR-V","Insight","Odyssey","Passport","Pilot","Prelude","Ridgeline","S2000" ]

,"Dodge" : ["Avenger","Caliber","Caravan","Challenger","Charger","Dart","Durango","Grand Caravan","Journey","Magnum","Neon","Nitro","Ram","Stratus","Viper"]

,"Lexus" : ["ES","GS","GX","IS","LC","LS","LX","NX","RC","RX","SC" ]

,"Jaguar" : [ "E-PACE","F-PACE","F-TYPE","S-TYPE","X-TYPE","XE","XF","XJ","XK"]

,"Buick" :["Century","Enclave","Encore","LaCrosse","LeSabre","Lucerne","Park Avenue","Rainier","Regal","Rendezvous","Riviera","Roadmaster","Skylark","Terraza","Verano"]

,"Chrysler" : ["200","300","Aspen","Crossfire","Pacifica","PT Cruiser","Sebring","Town and Country"]

,"Volvo" : ["240","740","760","850","940","C30","C70","S40","S60","S70","S80","V40","V50","V60","V70","XC40","XC60","XC70","XC90" ]

,"Audi" : ["100","200","A3","A4","A5","A6","A7","A8","Allroad","Q3","Q5","Q7","R8","RS3","RS4","RS5","RS6","S3","S4","S5","S6","S7","S8",'TT' ]

,"Infiniti" : [ "EX","FX","G20","G25","G35","G37","I30","I35","J30","M30","M35","M37","M45","Q30","Q40","Q45","Q50","Q60","Q70","QX30","QX4","QX50","QX56","Q"]

,"Lincoln" : ["Aviator", "Continental", "Corsair", "MKC", "MKT", "MKX", "MKZ", "Nautilus", "Navigator"]

,"Alfa_Romeo" : ["4C", "Giulia", "Mito", "Stelvio", "Spider"]

,"Subaru" : ["Ascent", "BRZ", "Crosstrek", "Forester", "Impreza", "Legacy", "Outback", "WRX"]

,"Acura" : ["ILX", "MDX", "NSX", "RDX", "RLX", "TLX"]

,"Hyundai" : ["Accent", "Elantra", "Genesis","h1", "i10", "i20","i30","i40", "Kona", "Palisade", "Santa Fe", "Sonata", "Tucson", "Veloster"]

,"Mercedes_Benz" :  ["A-Class", "C-Class", "E-Class", "S-Class", "GLE", "GLC", "GLA", "GLS","SL","AMG GT"]

,"Bmw" : ["2 Series", "3 Series", "4 Series", "5 Series", "7 Series", "X1", "X2", "X3", "X4", "X5", "X6", "X7", "Z3", "Z4"]

,"Mitsubishi" : ["ASX","Colt","Eclipse" ,"EVO","Galant", "Lancer","L200","Mirage", "Mirage G4","Montero", "Outlander", "Outlander PHEV","Space"]

,"Volkswagen" : ["Arteon", "Atlas", "Beetle","California", "Golf", "Jetta", "Scirocco","Passat", "Polo","Tiguan","Touran" "T-Roc"]

,"Porsche" : ["718", "911","Boxter","Cayman", "Cayenne","GT3", "Macan", "Panamera", "Taycan" ]

,"Kia" : ["Forte", "Niro", "Optima", "Rio", "Sedona", "Sorento", "Soul", "Sportage", "Stinger", "Telluride"]

,"Rover" : ["25","45", "75", "200", "220"]

,"Ferrari" : ["488", "812 Superfast", "California T", "F8 Spider", "GTC4Lusso", "Portofino", "Roma", "SF90 Stradale"]

,"Mini" : ["Clubman", "Cabrio", "Countryman", "Hardtop 2 Door", "Hardtop 4 Door" , "One"]

,"Pontiac" : [ "Aztek", "Fiero", "Firebird", "G6", "GTO", "Solstice", "Sunfire"]

,"Fiat" : ["Multipla","Doblo", "Ducato", "Panda", "Punto","124 Spider", "500", "500X", "500L"]

,"Tesla" :["Model S", "Model X", "Model 3", "Model Y", "Roadster"]

,"Saturn" :["Aura", "Ion", "Outlook", "Sky", "Vue"]

,"Mercury" : ["Grand Marquis", "Marauder", "Milan", "Montego", "Monterey", "Mountaineer", "Sable"]

,"Aston_Martin": ["DB9","DB11", "DBS Superleggera","DBX", "Rapide AMR", "Vantage", "Vanquish"]

,"Land_Rover": ["Defender", "Discovery","Evoque", "Sport", "Velar"]

,"Morgan" :["3 Wheeler", "Plus Four", "Roadster", "Plus Six"]}

# %%
df3 = df2.copy()

# %%
def modelo_cercano(marca, modelo, diccionario):
    try:
        models = diccionario[marca]
        closest_match = min(models, key=lambda x: distance(x, modelo.lower()))
        return closest_match
    except:
        return modelo


df2["model"] = df2.apply(lambda dataframe: modelo_cercano(dataframe["manufacturer"], dataframe["model"], dicc_marcas), axis = 1)

# %%
df2.head()
# Out:
#     price    year manufacturer         model  condition cylinders fuel  \
# 27  33590  2014.0          Gmc   Sierra 1500       good         8  gas
# 28  22590  2010.0    Chevrolet     Silverado       good         8  gas
# 29  39590  2020.0    Chevrolet     Silverado       good         8  gas
# 30  30990  2017.0       Toyota  Land Cruiser       good         8  gas
# 31  15000  2013.0         Ford         F-150  excellent         6  gas
#
#     odometer transmission drive    type paint_color state     lat     long
# 27   57923.0  desconocido   4wd  pickup       white    AL  32.590 -85.4800
# 28   71229.0  desconocido   4wd  pickup        blue    AL  32.590 -85.4800
# 29   19160.0  desconocido   4wd  pickup         red    AL  32.590 -85.4800
# 30   41124.0  desconocido   4wd  pickup         red    AL  32.590 -85.4800
# 31  128000.0    automatic   rwd   truck       black    AL  32.592 -85.5189

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 423754 entries, 27 to 426879
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         423754 non-null  int64
#  1   year          423754 non-null  object
#  2   manufacturer  423754 non-null  object
#  3   model         423754 non-null  object
#  4   condition     423754 non-null  object
#  5   cylinders     423754 non-null  object
#  6   fuel          423754 non-null  object
#  7   odometer      423754 non-null  object
#  8   transmission  423754 non-null  object
#  9   drive         423754 non-null  object
#  10  type          423754 non-null  object
#  11  paint_color   423754 non-null  object
#  12  state         423754 non-null  object
#  13  lat           423754 non-null  float64
#  14  long          423754 non-null  float64
# dtypes: float64(2), int64(1), object(12)
# memory usage: 67.9+ MB

# %%
df2[df2["manufacturer"]== "Desconocido"]
# Out:
#         price    year manufacturer                           model  \
# 97      15990  2016.0  Desconocido           Scion iM Hatchback 4D
# 122      6800  2005.0  Desconocido                   blue bird bus
# 135     14990  2016.0  Desconocido           Scion iM Hatchback 4D
# 137      2500  1966.0  Desconocido                 1966 C-30 1 ton
# 155      8990  2013.0  Desconocido  smart fortwo Passion Hatchback
# ...       ...     ...          ...                             ...
# 426843  21999  2017.0  Desconocido                            2017
# 426846  41999  2015.0  Desconocido                            2015
# 426862  27590  2018.0  Desconocido        Genesis G80 3.8 Sedan 4D
# 426863  25590  2017.0  Desconocido        Genesis G80 3.8 Sedan 4D
# 426869  13990  2016.0  Desconocido           Scion iM Hatchback 4D
#
#           condition    cylinders         fuel  odometer transmission drive  \
# 97             good  desconocido          gas   29652.0  desconocido   fwd
# 122       excellent            6       diesel  180000.0    automatic   rwd
# 135            good  desconocido          gas   65203.0  desconocido   fwd
# 137            good            6          gas   47000.0       manual   rwd
# 155            good  desconocido          gas   59072.0    automatic   rwd
# ...             ...          ...          ...       ...          ...   ...
# 426843  desconocido            4          gas   51000.0    automatic   4wd
# 426846  desconocido            4          gas  126000.0    automatic   4wd
# 426862         good            6          gas   36138.0  desconocido   rwd
# 426863         good            6          gas   37608.0    automatic   rwd
# 426869         good  desconocido  desconocido   75626.0  desconocido   fwd
#
#              type paint_color state      lat      long
# 97      hatchback        blue    AL  32.5900  -85.4800
# 122           bus      yellow    AL  32.8337  -85.1197
# 135     hatchback         red    AL  32.5900  -85.4800
# 137        pickup       brown    AL  32.4169  -85.7094
# 155         coupe      silver    AL  32.5900  -85.4800
# ...           ...         ...   ...      ...       ...
# 426843      sedan       black    WY  48.1783 -111.9397
# 426846      sedan        blue    WY  48.1783 -111.9397
# 426862      sedan       black    WY  33.7865  -84.4454
# 426863      sedan       white    WY  33.7865  -84.4454
# 426869  hatchback       white    WY  33.7865  -84.4454
#
# [15134 rows x 15 columns]

# %%
df2["model"][df2["manufacturer"]== "Datsun"]
df2["model"][df2["manufacturer"]== "Datsun"] = df2["model"][df2["manufacturer"]== "Datsun"].str.split(' ', expand=True)[0]

# %% [markdown]
# #### Harley es una marca de motos, y esto es un analisis de coches, asique se elimina del set de datos.

# %%
df2.drop(df2.index[df2["manufacturer"] == "Harley_Davidson"], axis = 0, inplace=True)

# %%
df2[df2["price"] == 0]
# Out:
#         price    year manufacturer          model    condition    cylinders  \
# 46          0  2011.0         Jeep        Compass    excellent            4
# 126         0  2018.0    Chevrolet        Express     like new            6
# 127         0  2019.0    Chevrolet        Express     like new            6
# 128         0  2018.0    Chevrolet        Express     like new            6
# 191         0  2015.0       Nissan         Sentra    excellent            4
# ...       ...     ...          ...            ...          ...          ...
# 426764      0  2018.0  Desconocido  peterbilt 579  desconocido  desconocido
# 426812      0  2006.0       Toyota           Echo    excellent            4
# 426832      0  2004.0       Toyota          Prius    excellent            4
# 426836      0  2018.0          Ram           2500    excellent            6
# 426868      0  2010.0       Toyota          Venza    excellent            6
#
#           fuel  odometer transmission drive       type paint_color state  \
# 46         gas   99615.0    automatic   fwd        SUV       white    AL
# 126        gas   68472.0    automatic   rwd        van       white    AL
# 127        gas   69125.0    automatic   rwd        van       white    AL
# 128        gas   66555.0    automatic   rwd        van       white    AL
# 191        gas   99505.0    automatic   fwd      sedan      silver    AL
# ...        ...       ...          ...   ...        ...         ...   ...
# 426764  diesel       1.0    automatic   rwd      truck       white    WY
# 426812     gas  195000.0    automatic   fwd  hatchback      silver    WY
# 426832  hybrid  239000.0    automatic   fwd  hatchback        blue    WY
# 426836  diesel   20492.0    automatic   4wd      truck       white    WY
# 426868     gas  155000.0    automatic   4wd        SUV        blue    WY
#
#               lat        long
# 46      32.547500  -85.468200
# 126     31.425091  -85.617723
# 127     31.425091  -85.617723
# 128     31.425091  -85.617723
# 191     33.614088  -85.796729
# ...           ...         ...
# 426764  42.862274 -106.307144
# 426812  40.114685 -104.971971
# 426832  40.114685 -104.971971
# 426836  45.082436  -94.334686
# 426868  40.114685 -104.971971
#
# [32393 rows x 15 columns]

# %%
df2.to_csv("datos/set_limpio.csv")

# %% [markdown]
# Eliminamos los precios que son igual a 0, ya que para el analisis son son utiles. Para el modelo predictivo se sustituiran.

# %%
df2.drop(df2.index[df2["price"] == 0], axis = 0, inplace=True)

# %% [markdown]
# ## Ya estan los datos limpios para proceder con el eda.

# %%
df2.to_csv("datos/set_limpio_sin0.csv")

# %%
df2.isnull().sum()
# Out:
# price           0
# year            0
# manufacturer    0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# drive           0
# type            0
# paint_color     0
# state           0
# lat             0
# long            0
# dtype: int64
